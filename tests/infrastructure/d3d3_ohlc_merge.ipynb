# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine.base import Engine
import clickhouse_connect
from sqlalchemy.orm import Session
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler

import os
import datetime
from urllib.parse import quote_plus

# %%
class DataWarehouse:
    DB_ADDRESS = os.getenv('DWH_HOST', '35.77.20.66')
    DB_PORT = os.getenv('DWH_PORT', '8123')
    DB_USER = os.getenv('DWH_USER', 'dwh_db')
    DB_PASSWORD = quote_plus(os.getenv('DWH_PASSWORD', 'dwh_db'))
    DB_NAME = os.getenv('DWH_DB', 'dwh_db')

    DB_URL = f'clickhouse://{DB_USER}:{DB_PASSWORD}@{DB_ADDRESS}/{DB_NAME}'

    @classmethod
    def get_client(cls):
        return clickhouse_connect.get_client(
            host=cls.DB_ADDRESS,
            port=cls.DB_PORT,
            username=cls.DB_USER,
            password=cls.DB_PASSWORD,
            database=cls.DB_NAME
        )

    @classmethod
    def get_session(cls) -> Session:
        s = Session(cls.get_engine())
        try:
            yield s
        finally:
            s.close()

    @classmethod
    def get_engine(cls) -> Engine:
        return create_engine(cls.get_uri())

    @classmethod
    def get_uri(cls) -> str:
        return cls.DB_URL
    
    @classmethod
    def read(cls, query, *args, **kwargs):
        return cls.get_client().query_df(query)

# %%
client = DataWarehouse()

# %%
Q = '''
    select
        h_ticker_name,
        h_exchange_name,
        max(pit_price) as high,
        min(pit_price) as low,
        argMin(pit_price, pit_ts) as open,
        argMax(pit_price, pit_ts) as close,
        pit_ts
    from 
        pit_big_table_whole_market_trades_history
    where
        h_ticker_name = 'MATICUSDT' and
        h_exchange_name = 'binance_usdt_m' and
        pit_ts > '2023-03-08 00:00:00' and
        pit_ts < '2023-03-09 00:00:00'
    group by
        toStartOfSecond(toDateTime64(pit_ts, 3)) as pit_ts,
        h_ticker_name,
        h_exchange_name
    order by
        pit_ts desc
'''

# %%
cex = client.read(Q)
cex.tail()
# Out:
#       h_ticker_name h_exchange_name    high     low    open   close  \
# 68444     MATICUSDT  binance_usdt_m  1.1498  1.1497  1.1498  1.1498
# 68445     MATICUSDT  binance_usdt_m  1.1497  1.1494  1.1497  1.1497
# 68446     MATICUSDT  binance_usdt_m  1.1496  1.1494  1.1495  1.1495
# 68447     MATICUSDT  binance_usdt_m  1.1498  1.1497  1.1497  1.1497
# 68448     MATICUSDT  binance_usdt_m  1.1500  1.1496  1.1498  1.1498
#
#                    pit_ts
# 68444 2023-03-08 00:00:09
# 68445 2023-03-08 00:00:08
# 68446 2023-03-08 00:00:07
# 68447 2023-03-08 00:00:05
# 68448 2023-03-08 00:00:04

# %%
cex.rename(
    columns={
        'pit_ts': 'ts'
    },
    inplace=True
)

# %%
Q = '''
    with agg as (
        select 
            *,
            addMilliseconds(toDateTime64(pit_ts, 3), pit_index_position_in_the_block) as ts
        from
          pit_big_table_bids_and_asks
        WHERE 
          ts BETWEEN '2023-03-08 00:00:00' and '2023-03-09 00:00:00' and
          h_protocol_name = 'uniswapV3' and
          pit_symbol = 'WMATIC/USDT'
        order by
          pit_ts asc
    ) select
        pit_symbol,
        h_protocol_name,
        max(pit_price) as high,
        min(pit_price) as low,
        argMin(pit_price, ts) as open,
        argMax(pit_price, ts) as close,
        ts
    from 
        agg
    group by
        toStartOfSecond(toDateTime64(ts, 3)) as ts,
        h_protocol_name,
        pit_symbol
    order by
        ts asc
'''

# %% [markdown]
# # №1

# %%
quickswapV3_wmatic_usdc_df = client.read(Q)
quickswapV3_wmatic_usdc_df.head()
# Out:
#     pit_symbol h_protocol_name      high       low      open     close  \
# 0  WMATIC/USDC     quickswapV3  1.150016  1.150016  1.150016  1.150016
# 1  WMATIC/USDC     quickswapV3  1.149030  1.149030  1.149030  1.149030
# 2  WMATIC/USDC     quickswapV3  1.150201  1.150201  1.150201  1.150201
# 3  WMATIC/USDC     quickswapV3  1.150281  1.150281  1.150281  1.150281
# 4  WMATIC/USDC     quickswapV3  1.150789  1.150530  1.150530  1.150530
#
#                    ts
# 0 2023-03-08 00:00:18
# 1 2023-03-08 00:00:46
# 2 2023-03-08 00:00:56
# 3 2023-03-08 00:01:12
# 4 2023-03-08 00:01:14

# %%
quickswapV3_wmatic_usdc_df.shape
# Out:
# (3387, 7)

# %%
quickswapV3_wmatic_usdc_df.rename(
    columns={
        'high': 'quickswapV3_wmatic_usdc_high',
        'low': 'quickswapV3_wmatic_usdc_low',
        'open': 'quickswapV3_wmatic_usdc_open',
        'close': 'quickswapV3_wmatic_usdc_close'
    },
    inplace=True
)

# %% [markdown]
# # №2

# %%
uniswapV3_wmatic_usdc_df = client.read(Q)
uniswapV3_wmatic_usdc_df.head()
# Out:
#     pit_symbol h_protocol_name      high       low      open     close  \
# 0  WMATIC/USDC       uniswapV3  1.149746  1.149746  1.149746  1.149746
# 1  WMATIC/USDC       uniswapV3  1.149806  1.149806  1.149806  1.149806
# 2  WMATIC/USDC       uniswapV3  1.149809  1.149809  1.149809  1.149809
# 3  WMATIC/USDC       uniswapV3  1.149916  1.149916  1.149916  1.149916
# 4  WMATIC/USDC       uniswapV3  1.150048  1.150048  1.150048  1.150048
#
#                    ts
# 0 2023-03-08 00:00:02
# 1 2023-03-08 00:00:06
# 2 2023-03-08 00:00:14
# 3 2023-03-08 00:00:16
# 4 2023-03-08 00:00:18

# %%
uniswapV3_wmatic_usdc_df.shape
# Out:
# (10194, 7)

# %%
uniswapV3_wmatic_usdc_df.rename(
    columns={
        'high': 'uniswapV3_wmatic_usdc_high',
        'low': 'uniswapV3_wmatic_usdc_low',
        'open': 'uniswapV3_wmatic_usdc_open',
        'close': 'uniswapV3_wmatic_usdc_close'
    },
    inplace=True
)

# %% [markdown]
# # №3

# %%
uniswapV3_wmatic_usdt_df = client.read(Q)
uniswapV3_wmatic_usdt_df.head()
# Out:
#     pit_symbol h_protocol_name      high       low      open     close  \
# 0  WMATIC/USDT       uniswapV3  1.150331  1.150215  1.150215  1.150215
# 1  WMATIC/USDT       uniswapV3  1.150425  1.150425  1.150425  1.150425
# 2  WMATIC/USDT       uniswapV3  1.150507  1.150507  1.150507  1.150507
# 3  WMATIC/USDT       uniswapV3  1.149415  1.149413  1.149413  1.149413
# 4  WMATIC/USDT       uniswapV3  1.150624  1.150624  1.150624  1.150624
#
#                    ts
# 0 2023-03-08 00:00:18
# 1 2023-03-08 00:00:22
# 2 2023-03-08 00:00:24
# 3 2023-03-08 00:00:36
# 4 2023-03-08 00:00:56

# %%
uniswapV3_wmatic_usdt_df.shape
# Out:
# (6982, 7)

# %%
uniswapV3_wmatic_usdt_df.rename(
    columns={
        'high': 'uniswapV3_wmatic_usdt_high',
        'low': 'uniswapV3_wmatic_usdt_low',
        'open': 'uniswapV3_wmatic_usdt_open',
        'close': 'uniswapV3_wmatic_usdt_close'
    },
    inplace=True
)

# %% [markdown]
# ## MERGE

# %%
df = uniswapV3_wmatic_usdc_df.merge(quickswapV3_wmatic_usdc_df, how='outer', on='ts').sort_values('ts').fillna(method='ffill').dropna()
df.head()
# Out:
#   pit_symbol_x h_protocol_name_x  uniswapV3_wmatic_usdc_high  \
# 4  WMATIC/USDC         uniswapV3                    1.150048
# 5  WMATIC/USDC         uniswapV3                    1.150227
# 6  WMATIC/USDC         uniswapV3                    1.149226
# 7  WMATIC/USDC         uniswapV3                    1.150474
# 8  WMATIC/USDC         uniswapV3                    1.149421
#
#    uniswapV3_wmatic_usdc_low  uniswapV3_wmatic_usdc_open  \
# 4                   1.150048                    1.150048
# 5                   1.150227                    1.150227
# 6                   1.149226                    1.149226
# 7                   1.149422                    1.150474
# 8                   1.149421                    1.149421
#
#    uniswapV3_wmatic_usdc_close                  ts pit_symbol_y  \
# 4                     1.150048 2023-03-08 00:00:18  WMATIC/USDC
# 5                     1.150227 2023-03-08 00:00:20  WMATIC/USDC
# 6                     1.149226 2023-03-08 00:00:22  WMATIC/USDC
# 7                     1.150474 2023-03-08 00:00:24  WMATIC/USDC
# 8                     1.149421 2023-03-08 00:00:40  WMATIC/USDC
#
#   h_protocol_name_y  quickswapV3_wmatic_usdc_high  \
# 4       quickswapV3                      1.150016
# 5       quickswapV3                      1.150016
# 6       quickswapV3                      1.150016
# 7       quickswapV3                      1.150016
# 8       quickswapV3                      1.150016
#
#    quickswapV3_wmatic_usdc_low  quickswapV3_wmatic_usdc_open  \
# 4                     1.150016                      1.150016
# 5                     1.150016                      1.150016
# 6                     1.150016                      1.150016
# 7                     1.150016                      1.150016
# 8                     1.150016                      1.150016
#
#    quickswapV3_wmatic_usdc_close
# 4                       1.150016
# 5                       1.150016
# 6                       1.150016
# 7                       1.150016
# 8                       1.150016

# %%
df = df.merge(uniswapV3_wmatic_usdt_df, how='outer', on='ts').sort_values('ts').fillna(method='ffill').dropna()
df.head()
# Out:
#       pit_symbol_x h_protocol_name_x  uniswapV3_wmatic_usdc_high  \
# 0      WMATIC/USDC         uniswapV3                    1.150048
# 1      WMATIC/USDC         uniswapV3                    1.150227
# 2      WMATIC/USDC         uniswapV3                    1.149226
# 3      WMATIC/USDC         uniswapV3                    1.150474
# 11650  WMATIC/USDC         uniswapV3                    1.150474
#
#        uniswapV3_wmatic_usdc_low  uniswapV3_wmatic_usdc_open  \
# 0                       1.150048                    1.150048
# 1                       1.150227                    1.150227
# 2                       1.149226                    1.149226
# 3                       1.149422                    1.150474
# 11650                   1.149422                    1.150474
#
#        uniswapV3_wmatic_usdc_close                  ts pit_symbol_y  \
# 0                         1.150048 2023-03-08 00:00:18  WMATIC/USDC
# 1                         1.150227 2023-03-08 00:00:20  WMATIC/USDC
# 2                         1.149226 2023-03-08 00:00:22  WMATIC/USDC
# 3                         1.150474 2023-03-08 00:00:24  WMATIC/USDC
# 11650                     1.150474 2023-03-08 00:00:36  WMATIC/USDC
#
#       h_protocol_name_y  quickswapV3_wmatic_usdc_high  \
# 0           quickswapV3                      1.150016
# 1           quickswapV3                      1.150016
# 2           quickswapV3                      1.150016
# 3           quickswapV3                      1.150016
# 11650       quickswapV3                      1.150016
#
#        quickswapV3_wmatic_usdc_low  quickswapV3_wmatic_usdc_open  \
# 0                         1.150016                      1.150016
# 1                         1.150016                      1.150016
# 2                         1.150016                      1.150016
# 3                         1.150016                      1.150016
# 11650                     1.150016                      1.150016
#
#        quickswapV3_wmatic_usdc_close   pit_symbol h_protocol_name  \
# 0                           1.150016  WMATIC/USDT       uniswapV3
# 1                           1.150016  WMATIC/USDT       uniswapV3
# 2                           1.150016  WMATIC/USDT       uniswapV3
# 3                           1.150016  WMATIC/USDT       uniswapV3
# 11650                       1.150016  WMATIC/USDT       uniswapV3
#
#        uniswapV3_wmatic_usdt_high  uniswapV3_wmatic_usdt_low  \
# 0                        1.150331                   1.150215
# 1                        1.150331                   1.150215
# 2                        1.150425                   1.150425
# 3                        1.150507                   1.150507
# 11650                    1.149415                   1.149413
#
#        uniswapV3_wmatic_usdt_open  uniswapV3_wmatic_usdt_close
# 0                        1.150215                     1.150215
# 1                        1.150215                     1.150215
# 2                        1.150425                     1.150425
# 3                        1.150507                     1.150507
# 11650                    1.149413                     1.149413

# %%
df = df.merge(cex, how='outer', on='ts').sort_values('ts').fillna(method='ffill').dropna()
df.head()
# Out:
#       pit_symbol_x h_protocol_name_x  uniswapV3_wmatic_usdc_high  \
# 0      WMATIC/USDC         uniswapV3                    1.150048
# 70501  WMATIC/USDC         uniswapV3                    1.150048
# 1      WMATIC/USDC         uniswapV3                    1.150227
# 70500  WMATIC/USDC         uniswapV3                    1.150227
# 2      WMATIC/USDC         uniswapV3                    1.149226
#
#        uniswapV3_wmatic_usdc_low  uniswapV3_wmatic_usdc_open  \
# 0                       1.150048                    1.150048
# 70501                   1.150048                    1.150048
# 1                       1.150227                    1.150227
# 70500                   1.150227                    1.150227
# 2                       1.149226                    1.149226
#
#        uniswapV3_wmatic_usdc_close                  ts pit_symbol_y  \
# 0                         1.150048 2023-03-08 00:00:18  WMATIC/USDC
# 70501                     1.150048 2023-03-08 00:00:19  WMATIC/USDC
# 1                         1.150227 2023-03-08 00:00:20  WMATIC/USDC
# 70500                     1.150227 2023-03-08 00:00:21  WMATIC/USDC
# 2                         1.149226 2023-03-08 00:00:22  WMATIC/USDC
#
#       h_protocol_name_y  quickswapV3_wmatic_usdc_high  ...  \
# 0           quickswapV3                      1.150016  ...
# 70501       quickswapV3                      1.150016  ...
# 1           quickswapV3                      1.150016  ...
# 70500       quickswapV3                      1.150016  ...
# 2           quickswapV3                      1.150016  ...
#
#        uniswapV3_wmatic_usdt_high  uniswapV3_wmatic_usdt_low  \
# 0                        1.150331                   1.150215
# 70501                    1.150331                   1.150215
# 1                        1.150331                   1.150215
# 70500                    1.150331                   1.150215
# 2                        1.150425                   1.150425
#
#        uniswapV3_wmatic_usdt_open uniswapV3_wmatic_usdt_close h_ticker_name  \
# 0                        1.150215                    1.150215     MATICUSDT
# 70501                    1.150215                    1.150215     MATICUSDT
# 1                        1.150215                    1.150215     MATICUSDT
# 70500                    1.150215                    1.150215     MATICUSDT
# 2                        1.150425                    1.150425     MATICUSDT
#
#        h_exchange_name    high     low    open   close
# 0       binance_usdt_m  1.1506  1.1503  1.1505  1.1505
# 70501   binance_usdt_m  1.1506  1.1506  1.1506  1.1506
# 1       binance_usdt_m  1.1506  1.1505  1.1505  1.1505
# 70500   binance_usdt_m  1.1505  1.1502  1.1503  1.1503
# 2       binance_usdt_m  1.1503  1.1503  1.1503  1.1503
#
# [5 rows x 25 columns]

# %%
df.to_csv('c3d3_ohlc.csv')

# %%
df.shape
# Out:
# (70499, 25)

# %%
df = df[df['uniswapV3_wmatic_usdt_close'] != 0]
